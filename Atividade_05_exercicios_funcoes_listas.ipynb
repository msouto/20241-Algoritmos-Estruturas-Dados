# %% [markdown]
# <a href="https://colab.research.google.com/github/msouto/20241-Algoritmos-Estruturas-Dados/blob/main/Atividade_05_exercicios_funcoes_listas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive  # Tratar Google Drive
import os                       # Acessar comandos do SO
import importlib.util           # Importação do arquivo
import unittest                 # Realizar os testes unitários

# Montando a pasta no Google Drive
drive.mount('/content/drive')

# Navegar para o diretório de destino
os.chdir('/content/drive/MyDrive/Colab Notebooks/20241_alg_est')

# Função para perguntar ao usuário o caminho do arquivo no Google Drive
def obter_caminho_arquivo():
    caminho = input("Digite o caminho completo do arquivo no Google Drive (ex: '/content/drive/MyDrive/Colab Notebooks/20241_alg_est/palindromo.ipynb'): ")
    print(f"O caminho fornecido foi: {caminho}")
    return caminho

# Converter notebook para script Python e importar o módulo
def importar_modulo(caminho_notebook):
    # Converter o notebook para um script Python
    # !jupyter nbconvert --to script "{caminho_notebook}"

    # Substituir a extensão '.ipynb' por '.py' para localizar o arquivo convertido
    caminho_py = caminho_notebook.replace('.ipynb', '.py')

    # Caso o arquivo tenha sido gerado como '.txt', renomeie para '.py'
    if os.path.exists(caminho_py.replace('.py', '.txt')):
        os.rename(caminho_py.replace('.py', '.txt'), caminho_py)

    # Importar o script Python gerado
    spec = importlib.util.spec_from_file_location("module", caminho_py)
    modulo = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(modulo)
    return modulo

#importar ja com caminhos
palindromo_module = importar_modulo("/content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_palindromo.ipynb")
contagem_module = importar_modulo("/content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_contagem.ipynb")
inverter_module = importar_modulo("/content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_inverter.ipynb")
converter_module = importar_modulo("/content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_converter.ipynb")
contar_module = importar_modulo("/content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_contar.ipynb")


# Importar os módulos
#palindromo_module = importar_modulo(obter_caminho_arquivo())
#contagem_module = importar_modulo(obter_caminho_arquivo())
#inverter_module = importar_modulo(obter_caminho_arquivo())
#converter_module = importar_modulo(obter_caminho_arquivo())
#contar_module = importar_modulo(obter_caminho_arquivo())

# Testes Unificados
class TestListaDeExercicios(unittest.TestCase):

    # Testes para o palíndromo
    def test_palindromo_simples(self):
        self.assertTrue(palindromo_module.eh_palindromo("radar"))

    def test_palindromo_com_espacos(self):
        self.assertTrue(palindromo_module.eh_palindromo("A man a plan a canal Panama"))

    def test_nao_palindromo(self):
        self.assertFalse(palindromo_module.eh_palindromo("algoritmo"))

    # Testes para contagem de palavras
    def test_contagem_palavra(self):
        with open("teste.txt", "w") as f:
            f.write("Ola mundo. O mundo é grande.")
        self.assertEqual(contagem_module.contar_palavra("teste.txt", "mundo"), 2)

    def test_palavra_nao_presente(self):
        with open("teste.txt", "w") as f:
            f.write("Ola universo.")
        self.assertEqual(contagem_module.contar_palavra("teste.txt", "mundo"), 0)

    # Testes para inverter string
    def test_inverter_simples(self):
        self.assertEqual(inverter_module.inverter_string("algoritmo"), "omtirgola")

    def test_inverter_com_espacos(self):
        self.assertEqual(inverter_module.inverter_string("estrutura de dados"), "sodad ed aruturtse")

    def test_inverter_vazio(self):
        self.assertEqual(inverter_module.inverter_string(""), "")

    # Testes para converter para maiúsculas
    def test_converter(self):
        with open("entrada.txt", "w") as f:
            f.write("Python é divertido.")
        converter_module.converter_para_maiusculas("entrada.txt", "saida.txt")
        with open("saida.txt", "r") as f:
            conteudo = f.read()
        self.assertEqual(conteudo, "PYTHON É DIVERTIDO.")

    # Testes para contar caracteres
    def test_contagem_simples(self):
        self.assertEqual(contar_module.contar_caracteres("abcabc"), {'a': 2, 'b': 2, 'c': 2})

    def test_contagem_com_espacos(self):
        self.assertEqual(contar_module.contar_caracteres("a b c a b c"), {'a': 2, ' ': 5, 'b': 2, 'c': 2})

    def test_contagem_vazio(self):
        self.assertEqual(contar_module.contar_caracteres(""), {})

if __name__ == '__main__':
    unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Digite o caminho completo do arquivo no Google Drive (ex: '/content/drive/MyDrive/Colab Notebooks/20241_alg_est/palindromo.ipynb'): /content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_palindromo.ipynb
# O caminho fornecido foi: /content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_palindromo.ipynb
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_palindromo.ipynb to script
# [NbConvertApp] Writing 123 bytes to /content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_palindromo.txt
# Digite o caminho completo do arquivo no Google Drive (ex: '/content/drive/MyDrive/Colab Notebooks/20241_alg_est/palindromo.ipynb'): /content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_contagem.ipynb
# O caminho fornecido foi: /content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_contagem.ipynb
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_contagem.ipynb to script
# [NbConvertApp] Writing 50 bytes to /content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_contagem.txt
# Digite o caminho completo do arquivo no Google Drive (ex: '/content/drive/MyDrive/Colab Notebooks/20241_alg_est/palindromo.ipynb'): /content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_converter.ipynb
# O caminho fornecido foi: /content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_converter.ipynb
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_converter.ipynb to script
# [NbConvertApp] Writing 63 bytes to /content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_converter.txt
# Digite o caminho completo do arquivo no Google Drive (ex: '/content/drive/MyDrive/Colab Notebooks/20241_alg_est/palindromo.ipynb'): /content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_converter.ipynb
# O caminho fornecido foi: /content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_converter.ipynb
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_converter.ipynb to script
# [NbConvertApp] Writing 63 bytes to /content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_converter.txt
# Digite o caminho completo do arquivo no Google Drive (ex: '/content/drive/MyDrive/Colab Notebooks/20241_alg_est/palindromo.ipynb'): /content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_contar.ipynb
# O caminho fornecido foi: /content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_contar.ipynb
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_contar.ipynb to script
# [NbConvertApp] Writing 39 bytes to /content/drive/MyDrive/Colab Notebooks/20241_alg_est/Atividade_05_contar.txt
# test_contagem_com_espacos (__main__.TestListaDeExercicios) ... FAIL
# test_contagem_palavra (__main__.TestListaDeExercicios) ... FAIL
# test_contagem_simples (__main__.TestListaDeExercicios) ... FAIL
# test_contagem_vazio (__main__.TestListaDeExercicios) ... FAIL
# test_converter (__main__.TestListaDeExercicios) ... ERROR
# test_inverter_com_espacos (__main__.TestListaDeExercicios) ... ERROR
# test_inverter_simples (__main__.TestListaDeExercicios) ... ERROR
# test_inverter_vazio (__main__.TestListaDeExercicios) ... ERROR
# test_nao_palindromo (__main__.TestListaDeExercicios) ... ok
# test_palavra_nao_presente (__main__.TestListaDeExercicios) ... FAIL
# test_palindromo_com_espacos (__main__.TestListaDeExercicios) ... FAIL
# test_palindromo_simples (__main__.TestListaDeExercicios) ... FAIL
#
# ======================================================================
# ERROR: test_converter (__main__.TestListaDeExercicios)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-5-036b58647a40>", line 82, in test_converter
#     with open("saida.txt", "r") as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'saida.txt'
#
# ======================================================================
# ERROR: test_inverter_com_espacos (__main__.TestListaDeExercicios)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-5-036b58647a40>", line 72, in test_inverter_com_espacos
#     self.assertEqual(inverter_module.inverter_string("estrutura de dados"), "sodad ed aruturtse")
# AttributeError: module 'module' has no attribute 'inverter_string'
#
# ======================================================================
# ERROR: test_inverter_simples (__main__.TestListaDeExercicios)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-5-036b58647a40>", line 69, in test_inverter_simples
#     self.assertEqual(inverter_module.inverter_string("algoritmo"), "omtirgola")
# AttributeError: module 'module' has no attribute 'inverter_string'
#
# ======================================================================
# ERROR: test_inverter_vazio (__main__.TestListaDeExercicios)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-5-036b58647a40>", line 75, in test_inverter_vazio
#     self.assertEqual(inverter_module.inverter_string(""), "")
# AttributeError: module 'module' has no attribute 'inverter_string'
#
# ======================================================================
# FAIL: test_contagem_com_espacos (__main__.TestListaDeExercicios)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-5-036b58647a40>", line 91, in test_contagem_com_espacos
#     self.assertEqual(contar_module.contar_caracteres("a b c a b c"), {'a': 2, ' ': 5, 'b': 2, 'c': 2})
# AssertionError: None != {'a': 2, ' ': 5, 'b': 2, 'c': 2}
#
# ======================================================================
# FAIL: test_contagem_palavra (__main__.TestListaDeExercicios)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-5-036b58647a40>", line 60, in test_contagem_palavra
#     self.assertEqual(contagem_module.contar_palavra("teste.txt", "mundo"), 2)
# AssertionError: None != 2
#
# ======================================================================
# FAIL: test_contagem_simples (__main__.TestListaDeExercicios)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-5-036b58647a40>", line 88, in test_contagem_simples
#     self.assertEqual(contar_module.contar_caracteres("abcabc"), {'a': 2, 'b': 2, 'c': 2})
# AssertionError: None != {'a': 2, 'b': 2, 'c': 2}
#
# ======================================================================
# FAIL: test_contagem_vazio (__main__.TestListaDeExercicios)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-5-036b58647a40>", line 94, in test_contagem_vazio
#     self.assertEqual(contar_module.contar_caracteres(""), {})
# AssertionError: None != {}
#
# ======================================================================
# FAIL: test_palavra_nao_presente (__main__.TestListaDeExercicios)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-5-036b58647a40>", line 65, in test_palavra_nao_presente
#     self.assertEqual(contagem_module.contar_palavra("teste.txt", "mundo"), 0)
# AssertionError: None != 0
#
# ======================================================================
# FAIL: test_palindromo_com_espacos (__main__.TestListaDeExercicios)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-5-036b58647a40>", line 51, in test_palindromo_com_espacos
#     self.assertTrue(palindromo_module.eh_palindromo("A man a plan a canal Panama"))
# AssertionError: None is not true
#
# ======================================================================
# FAIL: test_palindromo_simples (__main__.TestListaDeExercicios)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-5-036b58647a40>", line 48, in test_palindromo_simples
#     self.assertTrue(palindromo_module.eh_palindromo("radar"))
# AssertionError: None is not true
#
# ----------------------------------------------------------------------
# Ran 12 tests in 0.109s
#
# FAILED (failures=7, errors=4)
